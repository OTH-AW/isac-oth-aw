# %% [markdown]
# # Daten in MongoDB importieren

# %%
# %run ../Setup.ipynb

from isac.database.connection import database_connector as connector
from isac import configuration
import datetime
import time


importDirectory = "../../data/db_data_export/"
connection = connector.DatabaseConnector(name = configuration.project_database).connect()

# %% [markdown]
# # Vorsicht Limit für offene Dateien auf MacOS oder Linux anpassen
#
# ```ulimit -n``` liegt in der Regel bei 256 (MacOs High Sierra, Stand Februar 2019). Dieses wird beim Bearbeiten von mehr als 128 Files überschritten. Da hier immer ein Import einer Datei ausgeführt wird, auf der eine sofortige neue Connection zum Bearbeiten des TimeStamps geöffnet wird. Bei mehr als 128 Files wird bei Files * 2 auch das ulimit -n überschritten.
#
# ## ```ulimit -n 1024``` des für mongod-Session setzen
#
# Mit ```ulimit -n 1024``` wird via Terminal für die aktuelle Terminal-Session das File-Limit angepasst. Session-Max-Limit liegt bei 1024 (MacOS HighSierra, Stand Februar 2019).
# Damit auch das File-Limit für den entsprechend verantwortlichen ```mongod```an der richtigen Stelle greift, ist darauf zu achten, dass in der Session (also z.B. in dem Terminal-Fenster, in dem der mongod gestartet wird) des ```mongod``` das ulimit entsprechend gesetzt wird.

# %% [markdown]
# ### In Mongo speichern

# %%
def importFileIntoMongo(collection, file):
    print("Import File: " + str(file))
    exitcodeMassImport = connection.massImport(collection,
                                     file,
                                     'csv',
                                     True,
                                     '--fields',
                                     'Zeit,Wert')
    print("Exitcode Mass Import: " + str(exitcodeMassImport))
    return exitcodeMassImport

def addTimestamp(collection, timestamp):
    exitcode = connection.getCollection(collection).update_many(
        {},
        {
            '$inc': {'Zeit': timestamp}
        })
    return exitcode

for directory in os.listdir(importDirectory):
    path_sub_directory = os.path.join(importDirectory, directory)
    if os.path.isdir(path_sub_directory):
        year = int(directory.split("_")[0])
        month = int(directory.split("_")[1])
        day = int(directory.split("_")[2])
    
        for idx, filename in enumerate(os.listdir(path_sub_directory)):
            if filename.endswith(".csv"):
                print("File %i von %i" % (idx, len(os.listdir(path_sub_directory))))
                absFilePath = path_sub_directory + '/' + filename
                collection = os.path.splitext(filename)[0]
                importFileIntoMongo(collection, absFilePath)
                # Fix, da der Tag nicht in den Ursprungsdaten enthalten ist
                timestamp = datetime.datetime(year, month, day)
                unixtime = time.mktime(timestamp.timetuple()) * 1000
                addTimestamp(collection, unixtime)
                continue
            else:
                continue
# Out:
# File 0 von 144
# Import File: ../../data/db_data_export/2018_12_18/ET200S_ZS_K11_Meldungen.csv
# Exitcode Mass Import: 0
# File 1 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_4_K1_Befehle.csv
# Exitcode Mass Import: 0
# File 2 von 144
# Import File: ../../data/db_data_export/2018_12_18/Simocode_Q11M1_Leistungen.csv
# Exitcode Mass Import: 0
# File 3 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B01_Meldungen.csv
# Exitcode Mass Import: 0
# File 4 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S41_Meldungen.csv
# Exitcode Mass Import: 0
# File 5 von 144
# Import File: ../../data/db_data_export/2018_12_18/PSU8600_ZS_T1_Meldungen.csv
# Exitcode Mass Import: 0
# File 6 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_4_K6_Meldung.csv
# Exitcode Mass Import: 0
# File 7 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_ZS_Q10_Meldungen.csv
# Exitcode Mass Import: 0
# File 8 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S45_Meldungen.csv
# Exitcode Mass Import: 0
# File 9 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B12_Meldungen.csv
# Exitcode Mass Import: 0
# File 10 von 144
# Import File: ../../data/db_data_export/2018_12_18/ComfortPanel_Co_A2_Meldungen.csv
# Exitcode Mass Import: 0
# File 11 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_3_K1_Befehle.csv
# Exitcode Mass Import: 0
# File 12 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_1_K5_Meldung.csv
# Exitcode Mass Import: 0
# File 13 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_3_B03_Meldungen.csv
# Exitcode Mass Import: 0
# File 14 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikstation_0_Q30_Meldunge.csv
# Exitcode Mass Import: 0
# File 15 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S43_Befehle.csv
# Exitcode Mass Import: 0
# File 16 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_99_K5_Befehl.csv
# Exitcode Mass Import: 0
# File 17 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_1_K2_Befehle.csv
# Exitcode Mass Import: 0
# File 18 von 144
# Import File: ../../data/db_data_export/2018_12_18/ET200SP_ZS_K30_Befehle.csv
# Exitcode Mass Import: 0
# File 19 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_99_K6_Befehle.csv
# Exitcode Mass Import: 0
# File 20 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S46_Befehle.csv
# Exitcode Mass Import: 0
# File 21 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_Q14M4_Befehle.csv
# Exitcode Mass Import: 0
# File 23 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_99_K3_Befehle.csv
# Exitcode Mass Import: 0
# File 24 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_2_K1_Befehle.csv
# Exitcode Mass Import: 0
# File 25 von 144
# Import File: ../../data/db_data_export/2018_12_18/PÜberwachung_ZS_B103_Leistungen.csv
# Exitcode Mass Import: 0
# File 26 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_Q12M2_Meldungen.csv
# Exitcode Mass Import: 0
# File 27 von 144
# Import File: ../../data/db_data_export/2018_12_18/ComfortPanel_Co_A2_Befehle.csv
# Exitcode Mass Import: 0
# File 28 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_5_K6_Meldung.csv
# Exitcode Mass Import: 0
# File 29 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_2_B03_Meldungen.csv
# Exitcode Mass Import: 0
# File 30 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B02_Meldungen.csv
# Exitcode Mass Import: 0
# File 31 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikstation_0_Q30_Leistung.csv
# Exitcode Mass Import: 0
# File 32 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S42_Meldungen.csv
# Exitcode Mass Import: 0
# File 33 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B15_Meldungen.csv
# Exitcode Mass Import: 0
# File 34 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_ZS_Q7_Meldungen.csv
# Exitcode Mass Import: 0
# File 35 von 144
# Import File: ../../data/db_data_export/2018_12_18/Afagachse_US1_M1_Befehle.csv
# Exitcode Mass Import: 0
# File 36 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_5_K1_Befehle.csv
# Exitcode Mass Import: 0
# File 37 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M1_Leistungen.csv
# Exitcode Mass Import: 0
# File 38 von 144
# Import File: ../../data/db_data_export/2018_12_18/Simocode_Q11M1_Meldungen.csv
# Exitcode Mass Import: 0
# File 39 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B11_Meldungen.csv
# Exitcode Mass Import: 0
# File 40 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B06_Meldungen.csv
# Exitcode Mass Import: 0
# File 41 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S46_Meldungen.csv
# Exitcode Mass Import: 0
# File 42 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_5_K7_Befehle.csv
# Exitcode Mass Import: 0
# File 43 von 144
# Import File: ../../data/db_data_export/2018_12_18/PÜberwachung_ZS_B104_Leistungen.csv
# Exitcode Mass Import: 0
# File 44 von 144
# Import File: ../../data/db_data_export/2018_12_18/PSU8600_ZS_T1_Befehle.csv
# Exitcode Mass Import: 0
# File 45 von 144
# Import File: ../../data/db_data_export/2018_12_18/Leuchte_0_P1_Befehle.csv
# Exitcode Mass Import: 0
# File 46 von 144
# Import File: ../../data/db_data_export/2018_12_18/PSU8600_ZS_T1_Leistungen1.csv
# Exitcode Mass Import: 0
# File 47 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M1_Meldungen.csv
# Exitcode Mass Import: 0
# File 48 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_99_K5_Meldun.csv
# Exitcode Mass Import: 0
# File 49 von 144
# Import File: ../../data/db_data_export/2018_12_18/Afagachse_US1_M1_Meldungen.csv
# Exitcode Mass Import: 0
# File 50 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_5_K2_Befehle.csv
# Exitcode Mass Import: 0
# File 51 von 144
# Import File: ../../data/db_data_export/2018_12_18/PAC3200_ZS_P0_Leistungen.csv
# Exitcode Mass Import: 0
# File 52 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M3_Leistungen.csv
# Exitcode Mass Import: 0
# File 53 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_5_K5_Meldung.csv
# Exitcode Mass Import: 0
# File 54 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B08_Meldungen.csv
# Exitcode Mass Import: 0
# File 55 von 144
# Import File: ../../data/db_data_export/2018_12_18/PSU8600_ZS_T1_Leistungen2.csv
# Exitcode Mass Import: 0
# File 56 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_1_B03_Meldungen.csv
# Exitcode Mass Import: 0
# File 57 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_2_K2_Befehle.csv
# Exitcode Mass Import: 0
# File 58 von 144
# Import File: ../../data/db_data_export/2018_12_18/Simocode_Q11M1_Befehle.csv
# Exitcode Mass Import: 0
# File 59 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M4_Leistungen.csv
# Exitcode Mass Import: 0
# File 60 von 144
# Import File: ../../data/db_data_export/2018_12_18/SinamicsCU_US3_T100_Leistungen.csv
# Exitcode Mass Import: 0
# File 61 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_1_K3_Meldung.csv
# Exitcode Mass Import: 0
# File 62 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_ZS_Q7_Befehle.csv
# Exitcode Mass Import: 0
# File 63 von 144
# Import File: ../../data/db_data_export/2018_12_18/PSU8600_ZS_T1_Leistungen3.csv
# Exitcode Mass Import: 0
# File 64 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S45_Befehle.csv
# Exitcode Mass Import: 0
# File 65 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_1_K7_Befehle.csv
# Exitcode Mass Import: 0
# File 66 von 144
# Import File: ../../data/db_data_export/2018_12_18/PSU8600_ZS_T1_Leistungen7.csv
# Exitcode Mass Import: 0
# File 67 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_1_K1_Befehle.csv
# Exitcode Mass Import: 0
# File 68 von 144
# Import File: ../../data/db_data_export/2018_12_18/Leuchttaster_Co_S1P1_Meldungen.csv
# Exitcode Mass Import: 0
# File 69 von 144
# Import File: ../../data/db_data_export/2018_12_18/PSU8600_ZS_T1_Leistungen6.csv
# Exitcode Mass Import: 0
# File 70 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_3_K2_Befehle.csv
# Exitcode Mass Import: 0
# File 71 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_1_K6_Meldung.csv
# Exitcode Mass Import: 0
# File 72 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M2_Leistungen.csv
# Exitcode Mass Import: 0
# File 73 von 144
# Import File: ../../data/db_data_export/2018_12_18/PSU8600_ZS_T1_Leistungen4.csv
# Exitcode Mass Import: 0
# File 74 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M2_Meldungen.csv
# Exitcode Mass Import: 0
# File 75 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_ZS_Q10_Befehle.csv
# Exitcode Mass Import: 0
# File 76 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M3_Befehle.csv
# Exitcode Mass Import: 0
# File 77 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_4_K5_Meldung.csv
# Exitcode Mass Import: 0
# File 78 von 144
# Import File: ../../data/db_data_export/2018_12_18/EnergyMeter_ZS_K31_Leistungen.csv
# Exitcode Mass Import: 0
# File 79 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_4_K2_Befehle.csv
# Exitcode Mass Import: 0
# File 80 von 144
# Import File: ../../data/db_data_export/2018_12_18/PSU8600_ZS_T1_Leistungen5.csv
# Exitcode Mass Import: 0
# File 81 von 144
# Import File: ../../data/db_data_export/2018_12_18/Leistungsschalter_ZS_Q11_Q14_Me.csv
# Exitcode Mass Import: 0
# File 82 von 144
# Import File: ../../data/db_data_export/2018_12_18/PSU8600_ZS_T1_Leistungen8.csv
# Exitcode Mass Import: 0
# File 83 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_5_K6_Befehle.csv
# Exitcode Mass Import: 0
# File 84 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M4_Befehle.csv
# Exitcode Mass Import: 0
# File 85 von 144
# Import File: ../../data/db_data_export/2018_12_18/OPCUAGerät_6_Gerät1_Befehle.csv
# Exitcode Mass Import: 0
# File 86 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schlüsselschalter_Co_S3_Meldung.csv
# Exitcode Mass Import: 0
# File 87 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_5_K7_Meldung.csv
# Exitcode Mass Import: 0
# File 88 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_5_B02_Meldungen.csv
# Exitcode Mass Import: 0
# File 89 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_1_B01_Meldungen.csv
# Exitcode Mass Import: 0
# File 90 von 144
# Import File: ../../data/db_data_export/2018_12_18/OPCUAGerät_6_Gerät1_Meldungen.csv
# Exitcode Mass Import: 0
# File 91 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_99_K2_Befehle.csv
# Exitcode Mass Import: 0
# File 92 von 144
# Import File: ../../data/db_data_export/2018_12_18/SinamicsCU_US3_T100_Meldungen.csv
# Exitcode Mass Import: 0
# File 93 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_4_B01_Meldungen.csv
# Exitcode Mass Import: 0
# File 94 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M3_Meldungen.csv
# Exitcode Mass Import: 0
# File 95 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_3_K5_Befehle.csv
# Exitcode Mass Import: 0
# File 96 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B09_Meldungen.csv
# Exitcode Mass Import: 0
# File 97 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_2_K5_Befehle.csv
# Exitcode Mass Import: 0
# File 98 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_99_K7_Befehle.csv
# Exitcode Mass Import: 0
# File 99 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_1_K5_Befehle.csv
# Exitcode Mass Import: 0
# File 100 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M4_Meldungen.csv
# Exitcode Mass Import: 0
# File 101 von 144
# Import File: ../../data/db_data_export/2018_12_18/NotAus_Co_S2_Meldungen.csv
# Exitcode Mass Import: 0
# File 102 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_4_B02_Meldungen.csv
# Exitcode Mass Import: 0
# File 103 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S42_Befehle.csv
# Exitcode Mass Import: 0
# File 104 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_ZS_Q4_Q5_Meldungen.csv
# Exitcode Mass Import: 0
# File 105 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M1_Befehle.csv
# Exitcode Mass Import: 0
# File 106 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_Q12M2_Befehle.csv
# Exitcode Mass Import: 0
# File 107 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_Q13M3_Meldungen.csv
# Exitcode Mass Import: 0
# File 108 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_Q14M4_Meldungen.csv
# Exitcode Mass Import: 0
# File 109 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_1_B02_Meldungen.csv
# Exitcode Mass Import: 0
# File 110 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_5_B01_Meldungen.csv
# Exitcode Mass Import: 0
# File 111 von 144
# Import File: ../../data/db_data_export/2018_12_18/ET200S_ZS_K11_Befehle.csv
# Exitcode Mass Import: 0
# File 112 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_4_K6_Befehle.csv
# Exitcode Mass Import: 0
# File 113 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_4_K5_Befehle.csv
# Exitcode Mass Import: 0
# File 114 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikstation_0_Q30_Befehle.csv
# Exitcode Mass Import: 0
# File 115 von 144
# Import File: ../../data/db_data_export/2018_12_18/ET200SP_ZS_K30_Meldungen.csv
# Exitcode Mass Import: 0
# File 116 von 144
# Import File: ../../data/db_data_export/2018_12_18/SinamicsCU_US3_T100_Befehle.csv
# Exitcode Mass Import: 0
# File 117 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_3_B01_Meldungen.csv
# Exitcode Mass Import: 0
# File 118 von 144
# Import File: ../../data/db_data_export/2018_12_18/Sinamicsachse_US3_M2_Befehle.csv
# Exitcode Mass Import: 0
# File 119 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B07_Meldungen.csv
# Exitcode Mass Import: 0
# File 120 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B10_Meldungen.csv
# Exitcode Mass Import: 0
# File 121 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S41_Befehle.csv
# Exitcode Mass Import: 0
# File 122 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_1_K7_Meldung.csv
# Exitcode Mass Import: 0
# File 123 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_ZS_Q6_Meldungen.csv
# Exitcode Mass Import: 0
# File 124 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B14_Meldungen.csv
# Exitcode Mass Import: 0
# File 125 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_99_K4_Befehle.csv
# Exitcode Mass Import: 0
# File 126 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_2_K6_Befehle.csv
# Exitcode Mass Import: 0
# File 127 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_1_K6_Befehle.csv
# Exitcode Mass Import: 0
# File 128 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S43_Meldungen.csv
# Exitcode Mass Import: 0
# File 129 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_2_B02_Meldungen.csv
# Exitcode Mass Import: 0
# File 130 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_ZS_Q6_Befehle.csv
# Exitcode Mass Import: 0
# File 131 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_99_B13_Meldungen.csv
# Exitcode Mass Import: 0
# File 132 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_3_K6_Befehle.csv
# Exitcode Mass Import: 0
# File 133 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S44_Meldungen.csv
# Exitcode Mass Import: 0
# File 134 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schutztür_0_S44_Befehle.csv
# Exitcode Mass Import: 0
# File 135 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_1_K3_Befehle.csv
# Exitcode Mass Import: 0
# File 136 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_Q13M3_Befehle.csv
# Exitcode Mass Import: 0
# File 137 von 144
# Import File: ../../data/db_data_export/2018_12_18/IÜberwachung_ZS_B101_Leistungen.csv
# Exitcode Mass Import: 0
# File 138 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_2_B01_Meldungen.csv
# Exitcode Mass Import: 0
# File 139 von 144
# Import File: ../../data/db_data_export/2018_12_18/Pneumatikzylinder_99_K1_Befehle.csv
# Exitcode Mass Import: 0
# File 140 von 144
# Import File: ../../data/db_data_export/2018_12_18/Leuchttaster_Co_S1P1_Befehle.csv
# Exitcode Mass Import: 0
# File 141 von 144
# Import File: ../../data/db_data_export/2018_12_18/PneumatikzylinderÜ_5_K5_Befehle.csv
# Exitcode Mass Import: 0
# File 142 von 144
# Import File: ../../data/db_data_export/2018_12_18/Schütz_ZS_Q4_Q5_Befehle.csv
# Exitcode Mass Import: 0
# File 143 von 144
# Import File: ../../data/db_data_export/2018_12_18/Bandbero_3_B02_Meldungen.csv
# Exitcode Mass Import: 0
