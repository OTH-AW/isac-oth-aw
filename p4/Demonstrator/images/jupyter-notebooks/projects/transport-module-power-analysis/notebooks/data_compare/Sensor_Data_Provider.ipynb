# %% [markdown]
# ### Liest die Sensordaten für die Schnittstelle aus

# %%
# %run ../Setup.ipynb

import json
import numpy
import pandas as pd
from isac.database.connection import database_connector as connector
from isac import configuration

# %%
connection = connector.DatabaseConnector(name = configuration.project_database).connect()

# %%
class SensorDataProvider:
    
    def __init__(self):
        pass
    
    # Wird für die JSON-Konvertierung benötigt
    def handle_datatypes(self, o):
        if isinstance(o, numpy.int64): return int(o)  
        raise TypeError

    def getSensorData(self, sensorName):
        # getCollection
        collection = connection.getCollection(sensorName)

        # createDataframe 
        df = pd.DataFrame(list(collection.find()))

        are_bool_values = df.iloc[0]["Wert"] in ["False", "True"]
        if are_bool_values:
            df["Wert"] = df["Wert"].map({"False": 0, "True": 1})

        df = df.sort_values(by=['Zeit'])
        df = df.reset_index(drop=True)
        
        return df
        
    def getSensorDataAsJson(self, sensorName):
        df = self.getSensorData(sensorName)

        json_data = {}
        json_data['name'] = sensorName
        json_data['data'] = df[['Zeit', 'Wert']].to_dict(orient = 'records')

        return json.dumps(json_data, default=self.handle_datatypes)

# %%
# # Beispiel
# if __name__ == "__main__":
#    provider = SensorDataProvider()
#    sensorName = "Bandbero_99_B09_Meldungen"
#    sensor_data = provider.getSensorDataAsJson(sensorName)
#    
#    obj = json.loads(sensor_data)
#    obj
#    
#    file_path = "../../data/json/" + str(sensorName) + ".json"
#    os.makedirs(os.path.dirname(file_path), exist_ok=True)
#                
#    with open(file_path, "w") as f:
#        f.write(sensor_data)

# %%
if __name__ == "__main__":
    for collection in sorted(connection.getCollectionNames()):
        print(collection)
        provider = SensorDataProvider()
        sensorName = collection
        sensor_data = provider.getSensorDataAsJson(sensorName)

        file_path = "../../data/json/" + str(sensorName) + ".json"
        os.makedirs(os.path.dirname(file_path), exist_ok=True)

        with open(file_path, "w") as f:
            f.write(sensor_data)
# Out:
# Afagachse_US1_M1_Befehle
# Afagachse_US1_M1_Meldungen
# Bandbero_1_B01_Meldungen
# Bandbero_1_B02_Meldungen
# Bandbero_1_B03_Meldungen
# Bandbero_2_B01_Meldungen
# Bandbero_2_B02_Meldungen
# Bandbero_2_B03_Meldungen
# Bandbero_3_B01_Meldungen
# Bandbero_3_B02_Meldungen
# Bandbero_3_B03_Meldungen
# Bandbero_4_B01_Meldungen
# Bandbero_4_B02_Meldungen
# Bandbero_5_B01_Meldungen
# Bandbero_5_B02_Meldungen
# Bandbero_99_B01_Meldungen
# Bandbero_99_B02_Meldungen
# Bandbero_99_B06_Meldungen
# Bandbero_99_B07_Meldungen
# Bandbero_99_B08_Meldungen
# Bandbero_99_B09_Meldungen
# Bandbero_99_B10_Meldungen
# Bandbero_99_B11_Meldungen
# Bandbero_99_B12_Meldungen
# Bandbero_99_B13_Meldungen
# Bandbero_99_B14_Meldungen
# Bandbero_99_B15_Meldungen
# ComfortPanel_Co_A2_Befehle
# ComfortPanel_Co_A2_Meldungen
# ET200SP_ZS_K30_Befehle
# ET200SP_ZS_K30_Meldungen
# ET200S_ZS_K11_Befehle
# ET200S_ZS_K11_Meldungen
# EnergyMeter_ZS_K31_Leistungen
# IÜberwachung_ZS_B101_Leistungen
# Leistungsschalter_ZS_Q11_Q14_Me
# Leuchte_0_P1_Befehle
# Leuchttaster_Co_S1P1_Befehle
# Leuchttaster_Co_S1P1_Meldungen
# NotAus_Co_S2_Meldungen
# OPCUAGerät_6_Gerät1_Befehle
# OPCUAGerät_6_Gerät1_Meldungen
# PAC3200_ZS_P0_Leistungen
# PSU8600_ZS_T1_Befehle
# PSU8600_ZS_T1_Leistungen1
# PSU8600_ZS_T1_Leistungen2
# PSU8600_ZS_T1_Leistungen3
# PSU8600_ZS_T1_Leistungen4
# PSU8600_ZS_T1_Leistungen5
# PSU8600_ZS_T1_Leistungen6
# PSU8600_ZS_T1_Leistungen7
# PSU8600_ZS_T1_Leistungen8
# PSU8600_ZS_T1_Meldungen
# Pneumatikstation_0_Q30_Befehle
# Pneumatikstation_0_Q30_Leistung
# Pneumatikstation_0_Q30_Meldunge
# Pneumatikzylinder_1_K1_Befehle
# Pneumatikzylinder_1_K2_Befehle
# Pneumatikzylinder_2_K1_Befehle
# Pneumatikzylinder_2_K2_Befehle
# Pneumatikzylinder_2_K5_Befehle
# Pneumatikzylinder_2_K6_Befehle
# Pneumatikzylinder_3_K1_Befehle
# Pneumatikzylinder_3_K2_Befehle
# Pneumatikzylinder_3_K5_Befehle
# Pneumatikzylinder_3_K6_Befehle
# Pneumatikzylinder_4_K1_Befehle
# Pneumatikzylinder_4_K2_Befehle
# Pneumatikzylinder_5_K1_Befehle
# Pneumatikzylinder_5_K2_Befehle
# Pneumatikzylinder_99_K1_Befehle
# Pneumatikzylinder_99_K2_Befehle
# Pneumatikzylinder_99_K3_Befehle
# Pneumatikzylinder_99_K4_Befehle
# Pneumatikzylinder_99_K6_Befehle
# Pneumatikzylinder_99_K7_Befehle
# PneumatikzylinderÜ_1_K3_Befehle
# PneumatikzylinderÜ_1_K3_Meldung
# PneumatikzylinderÜ_1_K5_Befehle
# PneumatikzylinderÜ_1_K5_Meldung
# PneumatikzylinderÜ_1_K6_Befehle
# PneumatikzylinderÜ_1_K6_Meldung
# PneumatikzylinderÜ_1_K7_Befehle
# PneumatikzylinderÜ_1_K7_Meldung
# PneumatikzylinderÜ_4_K5_Befehle
# PneumatikzylinderÜ_4_K5_Meldung
# PneumatikzylinderÜ_4_K6_Befehle
# PneumatikzylinderÜ_4_K6_Meldung
# PneumatikzylinderÜ_5_K5_Befehle
# PneumatikzylinderÜ_5_K5_Meldung
# PneumatikzylinderÜ_5_K6_Befehle
# PneumatikzylinderÜ_5_K6_Meldung
# PneumatikzylinderÜ_5_K7_Befehle
# PneumatikzylinderÜ_5_K7_Meldung
# PneumatikzylinderÜ_99_K5_Befehl
# PneumatikzylinderÜ_99_K5_Meldun
# PÜberwachung_ZS_B103_Leistungen
# PÜberwachung_ZS_B104_Leistungen
# Schlüsselschalter_Co_S3_Meldung
# Schutztür_0_S41_Befehle
# Schutztür_0_S41_Meldungen
# Schutztür_0_S42_Befehle
# Schutztür_0_S42_Meldungen
# Schutztür_0_S43_Befehle
# Schutztür_0_S43_Meldungen
# Schutztür_0_S44_Befehle
# Schutztür_0_S44_Meldungen
# Schutztür_0_S45_Befehle
# Schutztür_0_S45_Meldungen
# Schutztür_0_S46_Befehle
# Schutztür_0_S46_Meldungen
# Schütz_Q12M2_Befehle
# Schütz_Q12M2_Meldungen
# Schütz_Q13M3_Befehle
# Schütz_Q13M3_Meldungen
# Schütz_Q14M4_Befehle
# Schütz_Q14M4_Meldungen
# Schütz_ZS_Q10_Befehle
# Schütz_ZS_Q10_Meldungen
# Schütz_ZS_Q4_Q5_Befehle
# Schütz_ZS_Q4_Q5_Meldungen
# Schütz_ZS_Q6_Befehle
# Schütz_ZS_Q6_Meldungen
# Schütz_ZS_Q7_Befehle
# Schütz_ZS_Q7_Meldungen
# Simocode_Q11M1_Befehle
# Simocode_Q11M1_Leistungen
# Simocode_Q11M1_Meldungen
# SinamicsCU_US3_T100_Befehle
# SinamicsCU_US3_T100_Leistungen
# SinamicsCU_US3_T100_Meldungen
# Sinamicsachse_US3_M1_Befehle
# Sinamicsachse_US3_M1_Leistungen
# Sinamicsachse_US3_M1_Meldungen
# Sinamicsachse_US3_M2_Befehle
# Sinamicsachse_US3_M2_Leistungen
# Sinamicsachse_US3_M2_Meldungen
# Sinamicsachse_US3_M3_Befehle
# Sinamicsachse_US3_M3_Leistungen
# Sinamicsachse_US3_M3_Meldungen
# Sinamicsachse_US3_M4_Befehle
# Sinamicsachse_US3_M4_Leistungen
# Sinamicsachse_US3_M4_Meldungen
